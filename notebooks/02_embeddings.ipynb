# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolaiberk/llm_ws/blob/main/notebooks/02_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to embedding manipulation with `gensim`

# %%
# !pip install gensim # restart after installation
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 72.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 84.5 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 15.5 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %% [markdown]
# ## Word Embeddings

# %%
## we load a 100-dimensional GloVe model trained on Wikipedia data
import gensim.downloader as api
wv = api.load('glove-wiki-gigaword-100') # small model so we don't have to wait too long...
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
wv['ziti'] # what do our embeddings look like?
# Out:
# array([ 0.049439 ,  0.33049  , -0.62916  ,  0.05941  , -0.070866 ,
#        -0.31198  ,  1.0051   , -0.36994  ,  0.51071  ,  0.88759  ,
#         0.30675  ,  0.41871  , -0.20705  ,  0.54854  ,  0.2315   ,
#        -0.10115  , -0.44656  ,  0.022504 ,  0.31798  ,  0.44769  ,
#        -0.50513  ,  0.34741  , -0.069257 ,  0.22331  ,  0.41969  ,
#         0.27958  ,  0.0037731, -0.22206  , -0.60191  , -0.67105  ,
#         0.1164   ,  0.099292 ,  0.16863  , -0.69876  ,  0.13203  ,
#         0.14845  ,  0.020125 , -0.40887  ,  0.15019  , -0.25258  ,
#         0.69223  , -0.24897  ,  0.047037 , -0.33101  , -0.16142  ,
#         0.10763  , -0.06854  , -0.29817  ,  0.15847  ,  0.92439  ,
#         0.52995  ,  0.89365  ,  0.56876  , -0.2421   , -0.78985  ,
#         0.75897  ,  0.53027  ,  0.53722  , -0.94077  ,  0.0013162,
#        -0.12927  , -0.10485  , -0.059788 , -0.56039  , -0.38289  ,
#        -0.43905  ,  0.02313  , -0.27358  , -0.086559 , -0.54393  ,
#        -0.49323  ,  0.14044  ,  0.50186  ,  0.11039  , -0.40333  ,
#         0.54352  , -0.14918  ,  0.069858 ,  1.028    ,  0.65854  ,
#        -0.14484  ,  0.06066  , -0.37153  ,  0.15011  , -0.12377  ,
#        -0.26727  ,  0.46632  ,  1.2429   , -0.077435 , -0.27101  ,
#         0.27347  , -0.078839 , -0.11403  ,  0.11122  , -0.015935 ,
#        -0.48769  ,  0.57196  ,  0.10234  , -0.10039  ,  0.043284 ],
#       dtype=float32)

# %% [markdown]
# ### Get most similar words

# %%
## so what are 'ziti' according to our model? Let's check the most similar embeddings:
print(wv.most_similar(positive=['ziti'], topn=5))
# Out:
# [('rigatoni', 0.7073923349380493), ('penne', 0.6969299912452698), ('focaccia', 0.6311710476875305), ('rotini', 0.6265588402748108), ('scrod', 0.6251025199890137)]

# %%
## you can assess the cosine similarity with
wv.similarity('ziti', 'penne')
# Out:
# 0.69693005

# %%
# Whereas
wv.similarity('ziti', 'banana')
# Out:
# 0.15077041

# %%
# and
wv.similarity('ziti', 'car')
# Out:
# -0.2821738

# %%
## You can calculate with these embeddings:
wv_london = wv['paris'] - wv['france'] + wv['england']
print(wv.most_similar(positive=[wv_london], topn=5))
# Out:
# [('london', 0.7929531931877136), ('england', 0.7346792221069336), ('melbourne', 0.7304184436798096), ('sydney', 0.7011193037033081), ('perth', 0.6856114864349365)]

# %%
## Though it does not always work perfectly
wv_queen = wv['king'] + wv['women'] - wv['men']
print(wv.most_similar(positive=[wv_queen], topn=5))
# Out:
# [('king', 0.8731269836425781), ('queen', 0.756426215171814), ('monarch', 0.7043204307556152), ('prince', 0.6424739360809326), ('kingdom', 0.6367932558059692)]

# %%
## you can also use the inbuilt function to get weighted averages
print(wv.most_similar(positive=['women', 'king'], negative=['men'], topn=5))
# Out:
# [('queen', 0.7415665984153748), ('monarch', 0.7021745443344116), ('prince', 0.6327081322669983), ('kingdom', 0.6294623017311096), ('elizabeth', 0.611503005027771)]

# %%
## other cute functions
print(wv.doesnt_match(['fire', 'water', 'land', 'sea', 'air', 'car']))
# Out:
# car

# %% [markdown]
# ### Use embeddings to scale words

# %%
## you can use the inbuilt gensim function to assess the similarity of embeddings
wv.similarity('nurse', 'woman')
# Out:
# 0.61394423

# %%
## ...or calculate by hand using numpy
from numpy import dot
from numpy.linalg import norm

def cos_sim(a, b):
    return dot(a, b)/(norm(a)*norm(b))

cos_sim(wv['nurse'], wv['woman'])
# Out:
# 0.6139443

# %%
## simple scaling

fr_de_scale = wv['french'] - wv['german']
print("Frenchness of Paris: ", cos_sim(wv['paris'], fr_de_scale))
print("Frenchness of Lausanne: ", cos_sim(wv['lausanne'], fr_de_scale))
print("Frenchness of Bern: ", cos_sim(wv['bern'], fr_de_scale))
print("Frenchness of Berlin: ", cos_sim(wv['berlin'], fr_de_scale))
# Out:
# Frenchness of Paris:  0.29809457
# Frenchness of Berlin:  -0.33290005
# Frenchness of Bern:  -0.17677024
# Frenchness of Lausanne:  0.07260391

# %%
## better: using centroids of several vectors to define poles

## define your dictionaries (ideally a bit larger than three words)
female_words = ['female', 'woman', 'feminine']
male_words = ['male', 'man', 'masculine']

# %%
## bonus: you can extend your dictionaries with embeddings!
wv.most_similar(positive=female_words, topn=5) # you could add relevant terms to your dictionary
# Out:
# [('male', 0.8363800048828125),
#  ('girl', 0.7304853200912476),
#  ('women', 0.7187752723693848),
#  ('masculine', 0.6826757192611694),
#  ('child', 0.6695144772529602)]

# %%
## create mean vectors for your concepts of interest
female_vec = np.mean(wv[female_words], axis = 0)
male_vec = np.mean(wv[male_words], axis = 0)

# %%
## what does this vector look like?
female_vec.shape

# %%
cos_sim(wv['nurse'], female_vec)
# Out:
# 0.5050166

# %%
cos_sim(wv['nurse'], male_vec)
# Out:
# 0.40162915

# %%
cos_sim(wv['banker'], female_vec)
# Out:
# 0.20321447

# %%
cos_sim(wv['banker'], male_vec)
# Out:
# 0.23747267

# %%
## cosine similarity difference
nurse_mf_cos = cos_sim(wv['nurse'], female_vec) - cos_sim(wv['nurse'], male_vec)
teacher_mf_cos = cos_sim(wv['teacher'], female_vec) - cos_sim(wv['teacher'], male_vec)
lifeguard_mf_cos = cos_sim(wv['lifeguard'], female_vec) - cos_sim(wv['lifeguard'], male_vec)
banker_mf_cos = cos_sim(wv['banker'], female_vec) - cos_sim(wv['banker'], male_vec)
miner_mf_cos = cos_sim(wv['miner'], female_vec) - cos_sim(wv['miner'], male_vec)

# %%
nurse_mf_cos # more female
# Out:
# 0.103387475

# %%
teacher_mf_cos
# Out:
# 0.023278862

# %%
lifeguard_mf_cos
# Out:
# 0.0648001

# %%
banker_mf_cos
# Out:
# -0.0342582

# %%
miner_mf_cos # more male
# Out:
# -0.006028235

# %% [markdown]
# We can also use the dot product to a given vector (= position of vector a on a given vector b):

# %%
## start by adding another scale
rich_words = ['rich', 'wealthy', 'wealth', 'billionaire']
poor_words = ['poor', 'broke', 'poverty', 'beggar']

rich_vec = np.mean(wv[rich_words], axis = 0)
poor_vec = np.mean(wv[poor_words], axis = 0)

# %%
## define axes
gender_axis = female_vec - male_vec
rich_axis = rich_vec - poor_vec

# %%
## calculate dot product for relative position on scale
np.dot(wv['nurse'], gender_axis)
# Out:
# 3.4711077

# %%
import numpy as np
import pandas as pd

scaled_occupations = pd.DataFrame(
    [['Nurse', 'Teacher', 'Lifeguard', 'Banker', 'Miner'],
    [
        np.dot(wv['nurse'], gender_axis),
        np.dot(wv['teacher'], gender_axis),
        np.dot(wv['lifeguard'], gender_axis),
        np.dot(wv['banker'], gender_axis),
        np.dot(wv['miner'], gender_axis)
    ],
    [
        np.dot(wv['nurse'], rich_axis),
        np.dot(wv['teacher'], rich_axis),
        np.dot(wv['lifeguard'], rich_axis),
        np.dot(wv['banker'], rich_axis),
        np.dot(wv['miner'], rich_axis)
    ]]
).T.rename(columns={0:'Occupation', 1:'Gender score', 2:'Economic Score'})

# %%
scaled_occupations
# Out:
#   Occupation Gender score Economic Score
# 0      Nurse     3.471108      -5.989534
# 1    Teacher     1.538335      -2.988986
# 2  Lifeguard     1.581818      -6.319327
# 3     Banker    -0.403989       9.930306
# 4      Miner     0.248439       3.270799

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(scaled_occupations['Gender score'], scaled_occupations['Economic Score'])

# Add labels and title
plt.xlabel('Gender Score (Higher = More Female)')
plt.ylabel('Economic Score (Higher = Richer)')
plt.title('Occupations Scaled by Gender and Status')

# Add text labels for each point
for i, row in scaled_occupations.iterrows():
    plt.text(row['Gender score'], row['Economic Score'], row['Occupation'])

plt.grid(True)
plt.show()

# %%
## in practice highly correlated (cos_sim is just a normalized dot product)
scaled_occupations['cos_dif_gender'] = [nurse_mf_cos, teacher_mf_cos, lifeguard_mf_cos, banker_mf_cos, miner_mf_cos]
scaled_occupations[['Gender score', 'cos_dif_gender']].corr()
# Out:
#                 Gender score  cos_dif_gender
# Gender score        1.000000        0.963181
# cos_dif_gender      0.963181        1.000000

# %% [markdown]
# ### Train a new model

# %% [markdown]
# We'll use an adapted dataset of dialogue in the Simpsons from [Kaggle](https://www.kaggle.com/datasets/prashant111/the-simpsons-dataset?resource=download&select=simpsons_script_lines.csv).

# %% [markdown]
# ![](https://media.giphy.com/media/v1.Y2lkPWVjZjA1ZTQ3cHA1dDZ5MWUwOWIyMmd3dHk3MGNyNGdvamEzc2w2dzVjdzdvMW5wOCZlcD12MV9naWZzX3NlYXJjaCZjdD1n/tkYpAbKdWj4TS/giphy.gif)

# %%
## load data
import pandas as pd
dataset = pd.read_csv('https://www.dropbox.com/scl/fi/n5ffxvm4qyjkp8ws7qgoq/simpsons_script_lines_clean.csv?rlkey=gfliitwgi8cqsjxlcdmmdwtym&dl=1')
dataset.head()
# Out:
#      id       raw_character_text  \
# 0  9549              Miss Hoover
# 1  9550             Lisa Simpson
# 2  9551              Miss Hoover
# 3  9552             Lisa Simpson
# 4  9553  Edna Krabappel-Flanders
#
#                                         spoken_words
# 0  No, actually, it was a little of both. Sometim...
# 1                             Where's Mr. Bergstrom?
# 2  I don't know. Although I'd sure like to talk t...
# 3                         That life is worth living.
# 4  The polls will be open from now until the end ...

# %%
## clean the texts (very rough here)
dataset['cleaned_text'] = dataset['spoken_words'].str.replace('[^a-zA-Z \d]','', regex=True) # remove anything that is not a letter or whitespace
dataset['cleaned_text'] = dataset['cleaned_text'].str.lower() # lowercase
dataset['cleaned_text'] = dataset['cleaned_text'].str.replace('\d+', '') # remove multiple whitespaces

# %%
dataset.cleaned_text.head()
# Out:
# 0    no actually it was a little of both sometimes ...
# 1                                  wheres mr bergstrom
# 2    i dont know although id sure like to talk to h...
# 3                            that life is worth living
# 4    the polls will be open from now until the end ...
# Name: cleaned_text, dtype: object

# %%
## filter empty rows and enforce string
dataset = dataset[dataset['cleaned_text'] != '']
dataset.loc[:,'cleaned_text'] = dataset['cleaned_text'].astype(str)

# %%
## how many texts are left?
dataset.shape
# Out:
# (158250, 4)

# %%
## create a list of lists of words by splitting along whitespaces
sentences = [s.split(" ") for s in dataset['cleaned_text']]

# %%
sentences[1]
# Out:
# ['wheres', 'mr', 'bergstrom']

# %%
## load dataset (use an iterator for larger datasets: https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html#training-your-own-model)
from gensim.models import Word2Vec

## estimate a model and save
model = Word2Vec(
    sentences=sentences,
    vector_size=100,  # number of dimensions of word embeddings
    window=5,         # number of context words in either direction to include
    min_count=5,      # how often must a word appear to enter the corpus?
    workers=4         # how many CPUs should be used to fit the model?
    )
model.save("simpsons.w2v.model")

# %%
## what is the main output?
model.wv.vectors.shape

# %%
## assess model
model.wv.most_similar('homer', topn=5)
# Out:
# [('bart', 0.8391718864440918),
#  ('marge', 0.8391621112823486),
#  ('lisa', 0.8119428753852844),
#  ('grampa', 0.7085936665534973),
#  ('abe', 0.7081788778305054)]

# %%
## subset words of interest
interesting_words = [
    'banana', 'pineapple', 'mango',
    'car', 'bike', 'motorcycle',
    'bart', 'lisa', 'homer']
interesting_vecs = wv[interesting_words]

# %%
## dimensionality reduction
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(interesting_vecs)
wv_2d = pca.transform(interesting_vecs)
wv_2d = pd.DataFrame(wv_2d, index = interesting_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4157242821.py in <cell line: 0>()
#       3
#       4 pca = PCA(n_components=2)
# ----> 5 pca.fit(interesting_vecs)
#       6 wv_2d = pca.transform(interesting_vecs)
#       7 wv_2d = pd.DataFrame(wv_2d, index = interesting_words)
#
# NameError: name 'interesting_vecs' is not defined

# %%
wv_2d
# Out:
#                    0         1
# banana      3.541008  1.041962
# pineapple   4.103635  1.062509
# mango       3.847255  0.803713
# car        -3.141653  2.390039
# bike       -2.633528  1.914495
# motorcycle -2.883574  2.724192
# bart       -1.347624 -3.186925
# lisa        0.255805 -3.397164
# homer      -1.741325 -3.352822

# %%
import matplotlib.pyplot as plt

plt.scatter(wv_2d[0], wv_2d[1])

for i in wv_2d.index:
    plt.annotate(i, (wv_2d[0][i], wv_2d[1][i]))

plt.show()

# %%
## subset words of interest
interesting_words = [
    'paris', 'berlin', 'france', 'germany']
interesting_vecs = wv[interesting_words]

# %%
## dimensionality reduction
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(interesting_vecs)
wv_2d = pca.transform(interesting_vecs)
wv_2d = pd.DataFrame(wv_2d, index = interesting_words)

# %%
import matplotlib.pyplot as plt
import random

random.seed(0)

plt.scatter(wv_2d[0], wv_2d[1])

for i in wv_2d.index:
    plt.annotate(i, (wv_2d[0][i], wv_2d[1][i]))

plt.show()

# %% [markdown]
# ## Speaker Embeddings

# %%
## concatenate all cleaned texts from the same speaker and tag documents (this runs a bit)
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
character_texts = list()
for speaker in dataset.raw_character_text.unique():
    print('Preparing texts from ', speaker, '...')
    concat_text = ' '.join(dataset[dataset.raw_character_text == speaker].cleaned_text)
    character_texts.append(TaggedDocument(concat_text.split(" "), [speaker]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Preparing texts from  Jumpsuited Guy ...
# Preparing texts from  Record/children ...
# Preparing texts from  Computer ...
# Preparing texts from  Messenger ...
# Preparing texts from  Mall Announcer ...
# Preparing texts from  Indian #1 ...
# Preparing texts from  Indian #2 ...
# Preparing texts from  Microchip Voice ...
# Preparing texts from  Jimbo's Dad ...
# Preparing texts from  Dolph's Dad ...
# Preparing texts from  Kearney's Dad ...
# Preparing texts from  Drederick Tatum ...
# Preparing texts from  LUCIUS ...
# Preparing texts from  Prisoners ...
# Preparing texts from  Questioner #1 ...
# Preparing texts from  Questioner #2 ...
# Preparing texts from  Questioner #3 ...
# Preparing texts from  PAROLE BOARD MEMBERS ...
# Preparing texts from  T-shirt Vendor ...
# Preparing texts from  Michael Buffer ...
# Preparing texts from  Referee ...
# Preparing texts from  Fan Man ...
# Preparing texts from  Park Ranger ...
# Preparing texts from  Tour Group ...
# Preparing texts from  Old Preppie ...
# Preparing texts from  Willy Loman ...
# Preparing texts from  Wealthy Dowager ...
# Preparing texts from  Male Admissions Officer ...
# Preparing texts from  Female Admissions Officer ...
# Preparing texts from  Costume Shop Clerk ...
# Preparing texts from  Child's Voice ...
# Preparing texts from  Simulated Homer ...
# Preparing texts from  Starlet ...
# Preparing texts from  Sports Announcer ...
# Preparing texts from  Dancer #1 ...
# Preparing texts from  Belle ...
# Preparing texts from  Rusty ...
# Preparing texts from  Bernice Hibbert ...
# Preparing texts from  Dancer #2 ...
# Preparing texts from  BELLE/DANCERS ...
# Preparing texts from  Townsmen Chorus ...
# Preparing texts from  Marge's Dummy ...
# Preparing texts from  Hibbert Family ...
# Preparing texts from  Kearney, Jr. ...
# Preparing texts from  Single Man ...
# Preparing texts from  Cracker Executive ...
# Preparing texts from  Chase ...
# Preparing texts from  Starla ...
# Preparing texts from  Flashback Homer ...
# Preparing texts from  Flashback Marge ...
# Preparing texts from  COMBO FRONTMAN ...
# Preparing texts from  Bandmembers ...
# Preparing texts from  Homer's Recording ...
# Preparing texts from  Milhouse's Thoughts ...
# Preparing texts from  Paramedic ...
# Preparing texts from  Nelson's Brain ...
# Preparing texts from  National Guardsman ...
# Preparing texts from  Main Title Singers ...
# Preparing texts from  Prison Officials ...
# Preparing texts from  Citizens ...
# Preparing texts from  Happy Man ...
# Preparing texts from  Young Dr. Foster ...
# Preparing texts from  Older Nurse ...
# Preparing texts from  Dr. Foster ...
# Preparing texts from  Young Ned ...
# Preparing texts from  Nedward Flanders, Sr. ...
# Preparing texts from  Mona Flanders ...
# Preparing texts from  Crazy Man ...
# Preparing texts from  Jay Sherman ...
# Preparing texts from  Various Onlookers ...
# Preparing texts from  Coyote ...
# Preparing texts from  Furniture Salesman ...
# Preparing texts from  First Mate ...
# Preparing texts from  Leonard Nimoy ...
# Preparing texts from  Video Arcade Man ...
# Preparing texts from  Kevin Costner Voice ...
# Preparing texts from  Guilty Man ...
# Preparing texts from  Fox Mulder ...
# Preparing texts from  Dana Scully ...
# Preparing texts from  Alf ...
# Preparing texts from  MARVIN-THE-MARTIAN-TYPE ...
# Preparing texts from  Whale ...
# Preparing texts from  Frog #1 ...
# Preparing texts from  Frog #2 ...
# Preparing texts from  Frog #3 ...
# Preparing texts from  alligator ...
# Preparing texts from  Hot Dog Stand Guy ...
# Preparing texts from  SMITHERS' ...
# Preparing texts from  NICK RIVIERA ...
# Preparing texts from  Motivational Man ...
# Preparing texts from  Picture Man ...
# Preparing texts from  Pita Saleswoman ...
# Preparing texts from  Investorettes ...
# Preparing texts from  Frank Ormand ...
# Preparing texts from  1st Sportscaster ...
# Preparing texts from  Entire Stadium ...
# Preparing texts from  2nd Sportscaster ...
# Preparing texts from  Mobster ...
# Preparing texts from  Little Yakuza ...
# Preparing texts from  Yakuza ...
# Preparing texts from  1st Panicked Employee ...
# Preparing texts from  2nd Panicked Employee ...
# Preparing texts from  Ranger ...
# Preparing texts from  Smokey Bear ...
# Preparing texts from  Smithers's Echo ...
# Preparing texts from  John Muir ...
# Preparing texts from  Drunk Man ...
# Preparing texts from  McFadden ...
# Preparing texts from  Mr. Burns's Thoughts ...
# Preparing texts from  Family ...
# Preparing texts from  FORD ...
# Preparing texts from  Older Woman ...
# Preparing texts from  Elderly Woman ...
# Preparing texts from  Nanny ...
# Preparing texts from  SHARY ...
# Preparing texts from  Fidgety Lieutenant ...
# Preparing texts from  Quentin Tarantino ...
# Preparing texts from  Moderator ...
# Preparing texts from  Writer #1 ...
# Preparing texts from  Writer #3 ...
# Preparing texts from  Writing Staff ...
# Preparing texts from  Head Animator ...
# Preparing texts from  Roy ...
# Preparing texts from  David Cohen ...
# Preparing texts from  Sound Engineer ...
# Preparing texts from  June ...
# Preparing texts from  Nerd In Audience ...
# Preparing texts from  Theme Singers ...
# Preparing texts from  Very Deep Voice ...
# Preparing texts from  Poochie ...
# Preparing texts from  Hip Saleswoman ...
# Preparing texts from  100 Workers ...
# Preparing texts from  Buffed Worker ...
# Preparing texts from  Worker In Crowd ...
# Preparing texts from  Convicts ...
# Preparing texts from  Fat Convict ...
# Preparing texts from  Cecil Terwilliger ...
# Preparing texts from  Sideshow Bob's Brain ...
# Preparing texts from  1986 Cecil ...
# Preparing texts from  1986 BOB ...
# Preparing texts from  1986 Krusty ...
# Preparing texts from  EVERYONE BUT BOB AND CECIL ...
# Preparing texts from  Cousin Merl ...
# Preparing texts from  Man In Lower Outhouse ...
# Preparing texts from  Comedy Nurse ...
# Preparing texts from  Distressed Yuppie ...
# Preparing texts from  Young Italian Man #1 ...
# Preparing texts from  Limo Driver ...
# Preparing texts from  Emergency Operator ...
# Preparing texts from  Irish Cops ...
# Preparing texts from  Drunken Revelers ...
# Preparing texts from  Shocked Old Woman ...
# Preparing texts from  Bar Crowd ...
# Preparing texts from  Temperance Women ...
# Preparing texts from  Very Old Clerk ...
# Preparing texts from  Councilmen ...
# Preparing texts from  Head Of Duff ...
# Preparing texts from  Quimby's Aide ...
# Preparing texts from  Rex Banner ...
# Preparing texts from  HOMER, MARGE AND BART ...
# Preparing texts from  Helpful Clerk ...
# Preparing texts from  Voice In Crowd ...
# Preparing texts from  Magician ...
# Preparing texts from  Cafeteria Worker ...
# Preparing texts from  Computerized Japanese Voice ...
# Preparing texts from  Laddie ...
# Preparing texts from  Credit Representative ...
# Preparing texts from  Frank Grimes ...
# Preparing texts from  Repo Goon #2 ...
# Preparing texts from  Heiress ...
# Preparing texts from  Lumley ...
# Preparing texts from  Distant Voice ...
# Preparing texts from  FIRE-STOKER ...
# Preparing texts from  Tommy ...
# Preparing texts from  Mitchell ...
# Preparing texts from  Stockbroker ...
# Preparing texts from  ADVISORS & SMITHERS ...
# Preparing texts from  Real Estate Agent ...
# Preparing texts from  Bret "The Hitman" Hart ...
# Preparing texts from  Shrieking Sheik ...
# Preparing texts from  Activity Coordinator ...
# Preparing texts from  Female Resident ...
# Preparing texts from  Male Resident ...
# Preparing texts from  Several Residents ...
# Preparing texts from  Hospital Intercom ...
# Preparing texts from  Test Blast Announcer ...
# Preparing texts from  Nearby Patient ...
# Preparing texts from  P.A. SYSTEM ...
# Preparing texts from  Young Flanders ...
# Preparing texts from  Young Lovejoy ...
# Preparing texts from  Japanese Worker #1 ...
# Preparing texts from  St. Eleutherius ...
# Preparing texts from  St. Bartholomew ...
# Preparing texts from  St. Lucian ...
# Preparing texts from  St. Donickus ...
# Preparing texts from  Japanese Businessman ...
# Preparing texts from  Mr. Sparkle ...
# Preparing texts from  UNDERWATER GIRLS #1 & #2 ...
# Preparing texts from  UNDERWATER GIRL #3 ...
# Preparing texts from  Sumo Wrestlers ...
# Preparing texts from  Japanese Announcer ...
# Preparing texts from  Donny ...
# Preparing texts from  Baboon ...
# Preparing texts from  Japanese Tourist ...
# Preparing texts from  Zookeeper ...
# Preparing texts from  Baboons ...
# Preparing texts from  City Employee ...
# Preparing texts from  Portly Chef ...
# Preparing texts from  Big Daddy ...
# Preparing texts from  Scary Huge-headed Figure ...
# Preparing texts from  Betty ...
# Preparing texts from  BETTY & MOE ...
# Preparing texts from  MOE & BETTY ...
# Preparing texts from  Tim Conway ...
# Preparing texts from  Ozmodiar ...
# Preparing texts from  OSMODIAR AND TROY ...
# Preparing texts from  Adlai Stevenson ...
# Preparing texts from  Parrots ...
# Preparing texts from  Commandant ...
# Preparing texts from  Cadet ...
# Preparing texts from  Cadet Larsen ...
# Preparing texts from  Cadet Franklin ...
# Preparing texts from  Cadet Platt ...
# Preparing texts from  Cadets ...
# Preparing texts from  CADET ANDERSEN ...
# Preparing texts from  Cadet Anderson ...
# Preparing texts from  Chauffeur ...
# Preparing texts from  Duffman ...
# Preparing texts from  Cheerleaders ...
# Preparing texts from  Hasidic Man ...
# Preparing texts from  Immigrants ...
# Preparing texts from  OFFICE WORKER IN TOWER ONE ...
# Preparing texts from  OFFICE WORKER IN TOWER TWO ...
# Preparing texts from  Undershirt Guy ...
# Preparing texts from  Dmv Recording ...
# Preparing texts from  Gruff Voice ...
# Preparing texts from  Crazy Guy ...
# Preparing texts from  Fireworks Vendor ...
# Preparing texts from  Society Matron ...
# Preparing texts from  Alfred E. Neuman ...
# Preparing texts from  Angry Cab Driver ...
# Preparing texts from  Bike Messenger ...
# Preparing texts from  Song On Radio ...
# Preparing texts from  Jury Member #1 ...
# Preparing texts from  Jury Member #2 ...
# Preparing texts from  Jury Chorus ...
# Preparing texts from  Mr. Cleary ...
# Preparing texts from  Staff/patients ...
# Preparing texts from  Construction Worker ...
# Preparing texts from  Picnickers ...
# Preparing texts from  Carriage Driver ...
# Preparing texts from  Student Choir ...
# Preparing texts from  Stranger ...
# Preparing texts from  Sgt. Skinner ...
# Preparing texts from  Armin ...
# Preparing texts from  Young Armin ...
# Preparing texts from  Frog ...
# Preparing texts from  Krusty ...
# Preparing texts from  Asian Boy ...
# Preparing texts from  Young Barney ...
# Preparing texts from  Little Girls ...
# Preparing texts from  Headmistress ...
# Preparing texts from  Man At Bar ...
# Preparing texts from  French President ...
# Preparing texts from  Mutant Sideshow Mel ...
# Preparing texts from  Mutant Dr. Hibbert ...
# Preparing texts from  Mutant Moe ...
# Preparing texts from  Mutant Skinner ...
# Preparing texts from  Mutant Burns ...
# Preparing texts from  Mutant Lenny ...
# Preparing texts from  Mutants ...
# Preparing texts from  Mutant Wiggum ...
# Preparing texts from  MUTANT FLANDERS ...
# Preparing texts from  MUTANT MEL/SKINNER/MOE/BURNS/WIGGUM ...
# Preparing texts from  Creature ...
# Preparing texts from  Fly-head ...
# Preparing texts from  Governor Quimby ...
# Preparing texts from  Constable Wiggum ...
# Preparing texts from  Goodman Skinner ...
# Preparing texts from  Goodman Flanders ...
# Preparing texts from  Pastor Lovejoy ...
# Preparing texts from  Goodman Moe ...
# Preparing texts from  Goody Krabappel ...
# Preparing texts from  Goodman Lenny ...
# Preparing texts from  Snowman Eddie ...
# Preparing texts from  Princess Lou ...
# Preparing texts from  Goody Maude ...
# Preparing texts from  Pelé ...
# Preparing texts from  Foreign Announcer ...
# Preparing texts from  Soccer Hooligans ...
# Preparing texts from  Soccer Hooligan ...
# Preparing texts from  Security Salesman ...
# Preparing texts from  Gun Clerk ...
# Preparing texts from  Hooker ...
# Preparing texts from  Muffled Voice ...
# Preparing texts from  Team ...
# Preparing texts from  Roy Firestone ...
# Preparing texts from  Teenage Smithers ...
# Preparing texts from  MIDDLE-AGE GRAMPA ...
# Preparing texts from  Teenage Lenny ...
# Preparing texts from  Joe Namath ...
# Preparing texts from  Other Players ...
# Preparing texts from  HANK ...
# Preparing texts from  Female Voices ...
# Preparing texts from  Female Crowd Members ...
# Preparing texts from  Manjula's Mother ...
# Preparing texts from  Elderly Gentleman ...
# Preparing texts from  Siegfried ...
# Preparing texts from  Stephen Jay Gould ...
# Preparing texts from  Guests ...
# Preparing texts from  Ganesh ...
# Preparing texts from  Burly Guest ...
# Preparing texts from  Indian Singers ...
# Preparing texts from  Mall Executive ...
# Preparing texts from  Pr Man ...
# Preparing texts from  Caveman ...
# Preparing texts from  SOUTH AMERICAN BIDDER ...
# Preparing texts from  Johnny D ...
# Preparing texts from  City Clerk ...
# Preparing texts from  Gil Gunderson ...
# Preparing texts from  Cookie ...
# Preparing texts from  Assorted Agents ...
# Preparing texts from  Lionel Hutz's Head ...
# Preparing texts from  Female Victim ...
# Preparing texts from  Other Realtors ...
# Preparing texts from  Dove ...
# Preparing texts from  Shopper ...
# Preparing texts from  Cheerleader ...
# Preparing texts from  Toy ...
# Preparing texts from  Cooder ...
# Preparing texts from  Patches ...
# Preparing texts from  Poor Violet ...
# Preparing texts from  Sullen Teen ...
# Preparing texts from  Sean ...
# Preparing texts from  Alex Trebek ...
# Preparing texts from  Goon #1 ...
# Preparing texts from  Hombre ...
# Preparing texts from  Clint Eastwood ...
# Preparing texts from  Townspeople Chorus ...
# Preparing texts from  Lee Marvin ...
# Preparing texts from  Female Chorus ...
# Preparing texts from  SECOND FEMALE CHORUS ...
# Preparing texts from  Kids On Ride ...
# Preparing texts from  Carny ...
# Preparing texts from  Dracula Voice ...
# Preparing texts from  Maintenance Man ...
# Preparing texts from  Game Announcer ...
# Preparing texts from  Spud ...
# Preparing texts from  Performer ...
# Preparing texts from  Camel ...
# Preparing texts from  Fantastic Dan ...
# Preparing texts from  Passengers ...
# Preparing texts from  Hari Krishna ...
# Preparing texts from  Christian ...
# Preparing texts from  Jane ...
# Preparing texts from  Glen ...
# Preparing texts from  Player #1 ...
# Preparing texts from  Movementarians ...
# Preparing texts from  Don ...
# Preparing texts from  Homer's Stomach ...
# Preparing texts from  Homer's Feet ...
# Preparing texts from  Leader ...
# Preparing texts from  THE LEADER ...
# Preparing texts from  Noah ...
# Preparing texts from  Singing Children ...
# Preparing texts from  Chinese Sailor #1 ...
# Preparing texts from  Chinese Sailor #2 ...
# Preparing texts from  Bill Gates ...
# Preparing texts from  James Earl Jones ...
# Preparing texts from  Volunteer ...
# Preparing texts from  Steven Wright ...
# Preparing texts from  Bobcat Goldthwaite ...
# Preparing texts from  JANEANE ...
# Preparing texts from  Bruce Baum ...
# Preparing texts from  COMPUTER ON STOOL ...
# Preparing texts from  Comics ...
# Preparing texts from  Mr. Teeny ...
# Preparing texts from  Businessman #1 ...
# Preparing texts from  Businessman #2 ...
# Preparing texts from  Jay Leno ...
# Preparing texts from  Renee ...
# Preparing texts from  HANK WILLIAMS JR. ...
# Preparing texts from  Republican Candidate ...
# Preparing texts from  Drunken Cop ...
# Preparing texts from  Photographer Cop ...
# Preparing texts from  Homer's Voice ...
# Preparing texts from  GHOSTLY HOMER ...
# Preparing texts from  Station Manager ...
# Preparing texts from  Square Guy ...
# Preparing texts from  Great Uncle Chet ...
# Preparing texts from  Stanley ...
# Preparing texts from  Well-dressed Relative ...
# Preparing texts from  Relative #1 ...
# Preparing texts from  Relative #2 ...
# Preparing texts from  Relative #3 ...
# Preparing texts from  Relative #4 ...
# Preparing texts from  Relative #5 ...
# Preparing texts from  Dr. Simpson ...
# Preparing texts from  Simpson Woman #1 ...
# Preparing texts from  Simpson Woman #2 ...
# Preparing texts from  Simpson Woman #3 ...
# Preparing texts from  Nerdy Kids ...
# Preparing texts from  Female Computer ...
# Preparing texts from  Bullies ...
# Preparing texts from  Elderly Night Watchman ...
# Preparing texts from  Leprechaun ...
# Preparing texts from  General Donut ...
# Preparing texts from  Donuts ...
# Preparing texts from  Roddy McDonut ...
# Preparing texts from  Big Donut ...
# Preparing texts from  Big Hand Guy ...
# Preparing texts from  Naval Announcer ...
# Preparing texts from  Recruiting Officer ...
# Preparing texts from  Asian Man ...
# Preparing texts from  Drill Instructor ...
# Preparing texts from  Barney's Mom ...
# Preparing texts from  Head Chef ...
# Preparing texts from  Head Instructor ...
# Preparing texts from  WORLD WAR I RECREATIONISTS ...
# Preparing texts from  Other Kids ...
# Preparing texts from  Bob Denver ...
# Preparing texts from  Captain Tenille ...
# Preparing texts from  Female Ensign ...
# Preparing texts from  Enemy Crewperson ...
# Preparing texts from  Enemy Captain ...
# Preparing texts from  Asian Ensign ...
# Preparing texts from  Hick ...
# Preparing texts from  Russian Ambassador ...
# Preparing texts from  U.S. Ambassador ...
# Preparing texts from  Lenin ...
# Preparing texts from  Sonar Operator ...
# Preparing texts from  AIRCRAFT CARRIER CAPTAIN ...
# Preparing texts from  Thought Bubble Moe ...
# Preparing texts from  Thought Bubble Bart ...
# Preparing texts from  Penguins ...
# Preparing texts from  Admiral #1 ...
# Preparing texts from  Admiral #3 ...
# Preparing texts from  Admiral #4 ...
# Preparing texts from  Janitor ...
# Preparing texts from  Myron ...
# Preparing texts from  Agent Miller ...
# Preparing texts from  Lucius Sweet ...
# Preparing texts from  Mission Impossible Voice ...
# Preparing texts from  Truman ...
# Preparing texts from  British Official ...
# Preparing texts from  Spanish Official ...
# Preparing texts from  French Official ...
# Preparing texts from  Customs Official ...
# Preparing texts from  Street Vendor ...
# Preparing texts from  Castro ...
# Preparing texts from  Cuban Officials ...
# Preparing texts from  Cuban Undersecretary ...
# Preparing texts from  Agency Clerk ...
# Preparing texts from  Mojo ...
# Preparing texts from  Cat Lady ...
# Preparing texts from  Computer Voice ...
# Preparing texts from  Head Chocobot ...
# Preparing texts from  Major Nougat ...
# Preparing texts from  All Chocobots ...
# Preparing texts from  Young Exec ...
# Preparing texts from  Older Exec ...
# Preparing texts from  Female Exec ...
# Preparing texts from  Other Executives ...
# Preparing texts from  Garbage Man #1 ...
# Preparing texts from  Garbage Man #2 ...
# Preparing texts from  Ray Magini ...
# Preparing texts from  Paul ...
# Preparing texts from  Susie ...
# Preparing texts from  Bono ...
# Preparing texts from  The Edge ...
# Preparing texts from  Adam Clayton ...
# Preparing texts from  Security Guys ...
# Preparing texts from  A Few People ...
# Preparing texts from  Giant-nosed Man ...
# Preparing texts from  Garbage Men ...
# Preparing texts from  U2 ...
# Preparing texts from  Oskar ...
# Preparing texts from  Union Leader ...
# Preparing texts from  Second Indian ...
# Preparing texts from  First Indian ...
# Preparing texts from  Commie Nazi ...
# Preparing texts from  Other Team ...
# Preparing texts from  Muscular Man ...
# Preparing texts from  Brad ...
# Preparing texts from  Sherpa #1 ...
# Preparing texts from  Sherpa #2 ...
# Preparing texts from  Sherpas ...
# Preparing texts from  Geese ...
# Preparing texts from  Faucet-head Kid's Mother ...
# Preparing texts from  Soldier ...
# Preparing texts from  Russian Man #1 ...
# Preparing texts from  Russian Man #2 ...
# Preparing texts from  HOMER'S VOICE MAIL ...
# Preparing texts from  FISH-HAG ...
# Preparing texts from  Telephone Repairman ...
# Preparing texts from  Bridge Operator ...
# Preparing texts from  Cow ...
# Preparing texts from  Studio Audience ...
# Preparing texts from  Pirate Captain ...
# Preparing texts from  Pirate #1 ...
# Preparing texts from  Ilsa ...
# Preparing texts from  Golf Course Crowd ...
# Preparing texts from  Minister ...
# Preparing texts from  Stadium Announcer ...
# Preparing texts from  Stadium Crowd ...
# Preparing texts from  Kicker ...
# Preparing texts from  Edison's Ghost ...
# Preparing texts from  Alex ...
# Preparing texts from  Thug #1 ...
# Preparing texts from  Thug #2 ...
# Preparing texts from  Cardinal Flanders ...
# Preparing texts from  President Lenny ...
# Preparing texts from  Heckle ...
# Preparing texts from  Jeckle ...
# Preparing texts from  Passerby ...
# Preparing texts from  Visitor ...
# Preparing texts from  Female Visitor ...
# Preparing texts from  Leavelle ...
# Preparing texts from  Eagle ...
# Preparing texts from  Toucan ...
# Preparing texts from  Vulture ...
# Preparing texts from  Birds ...
# Preparing texts from  Library Lady Tress ...
# Preparing texts from  Birders ...
# Preparing texts from  Ed McMahon ...
# Preparing texts from  Regis Philbin ...
# Preparing texts from  KATHIE LEE ...
# Preparing texts from  Jerry Springer ...
# Preparing texts from  Woman In Audience ...
# Preparing texts from  Homie Bear ...
# Preparing texts from  BART BART ...
# Preparing texts from  Ranger Ned ...
# Preparing texts from  Kim Basinger ...
# Preparing texts from  Alec Baldwin ...
# Preparing texts from  Ron Howard ...
# Preparing texts from  Gentleman ...
# Preparing texts from  ALEC/KIM ...
# Preparing texts from  ALEC/KIM/RON ...
# Preparing texts from  STUDIO EXECUTIVE ...
# Preparing texts from  Munchie ...
# Preparing texts from  Seth ...
# Preparing texts from  Middle-aged Grampa ...
# Preparing texts from  Young Mona ...
# Preparing texts from  Young Munchie ...
# Preparing texts from  Young Seth ...
# Preparing texts from  Hippie Girl #1 ...
# Preparing texts from  Hippie Girl #2 ...
# Preparing texts from  Ginsberg ...
# Preparing texts from  Jill St. John ...
# Preparing texts from  Phyllis Diller ...
# Preparing texts from  Sarah Ferguson ...
# Preparing texts from  Skeleton ...
# Preparing texts from  Lips ...
# Preparing texts from  Range-rover Mom ...
# Preparing texts from  Lobster Clerk ...
# Preparing texts from  Documentary Narrator ...
# Preparing texts from  Taskmaster ...
# Preparing texts from  Mr. Toad ...
# Preparing texts from  President Of Harvard ...
# Preparing texts from  Comptroller Atkins ...
# Preparing texts from  REAL COMPT. ATKINS ...
# Preparing texts from  Robot Cowboy #1 ...
# Preparing texts from  Robot Cowboy #2 ...
# Preparing texts from  Robot Cowboy #3 ...
# Preparing texts from  Curly ...
# Preparing texts from  Old Curly ...
# Preparing texts from  3-Year-Old Homer ...
# Preparing texts from  Admitting Nurse ...
# Preparing texts from  Taffy Shop Clerk ...
# Preparing texts from  Sad-looking Frenchman ...
# Preparing texts from  Man In Dinner Jacket ...
# Preparing texts from  British Raj Man ...
# Preparing texts from  Woman In Wedding Dress ...
# Preparing texts from  Caribbean Outcast ...
# Preparing texts from  Son ...
# Preparing texts from  Young Woman ...
# Preparing texts from  Hideous Alien #1 ...
# Preparing texts from  Hideous Alien #2 ...
# Preparing texts from  C-3PO ...
# Preparing texts from  Chewbacca ...
# Preparing texts from  Neil Armstrong ...
# Preparing texts from  Dr. Smith ...
# Preparing texts from  Nerdy Young Woman ...
# Preparing texts from  Crowd Of Nerds ...
# Preparing texts from  Mark Hamill ...
# Preparing texts from  Ernie ...
# Preparing texts from  Big Tom ...
# Preparing texts from  Gangsters/molls ...
# Preparing texts from  Theater Owner ...
# Preparing texts from  Demolition Foreman ...
# Preparing texts from  Don Rickles ...
# Preparing texts from  Car Wash Employee ...
# Preparing texts from  Babe ...
# Preparing texts from  Samoan Attorney ...
# Preparing texts from  Hunter S. Thompson ...
# Preparing texts from  Joan Rivers ...
# Preparing texts from  LANCE ...
# Preparing texts from  Pit Boss ...
# Preparing texts from  WAITRESS #1 ...
# Preparing texts from  Ginger ...
# Preparing texts from  Tiger ...
# Preparing texts from  Graeme Edge ...
# Preparing texts from  Justin Hayward ...
# Preparing texts from  John Lodge ...
# Preparing texts from  Ray Thomas ...
# Preparing texts from  VULTURES ...
# Preparing texts from  Cyndi Lauper ...
# Preparing texts from  Dennis Conroy ...
# Preparing texts from  Deep-voiced Announcer ...
# Preparing texts from  WHINY TWENTYSOMETHING GUY ...
# Preparing texts from  SASSY TWENTYSOMETHING GAL ...
# Preparing texts from  Wacky Friend ...
# Preparing texts from  Higher Nasal Announcer ...
# Preparing texts from  Mrs. Muntz ...
# Preparing texts from  Craggy Farmer ...
# Preparing texts from  Creepy English Boy #2 ...
# Preparing texts from  Creepy English Girl #1 ...
# Preparing texts from  Constable ...
# Preparing texts from  Creepy English Girl #2 ...
# Preparing texts from  Townsfolk ...
# Preparing texts from  Pyro ...
# Preparing texts from  Adults ...
# Preparing texts from  Postmaster Bill ...
# Preparing texts from  Man In Military Uniform ...
# Preparing texts from  Government Official ...
# Preparing texts from  Mailman #1 ...
# Preparing texts from  Mailman #2 ...
# Preparing texts from  Mailman #3 ...
# Preparing texts from  Wally ...
# Preparing texts from  Guys ...
# Preparing texts from  Rudy ...
# Preparing texts from  Rosey Grier ...
# Preparing texts from  Old Player ...
# Preparing texts from  Little Guy ...
# Preparing texts from  Troy Aikman ...
# Preparing texts from  Dan Marino ...
# Preparing texts from  Man Next To Dan ...
# Preparing texts from  Male Voice ...
# Preparing texts from  Vincent Price ...
# Preparing texts from  Ticket Scalper ...
# Preparing texts from  Pat Summerall ...
# Preparing texts from  John Madden ...
# Preparing texts from  Dolly Parton ...
# Preparing texts from  Rupert Murdoch ...
# Preparing texts from  Enchanted Policemen ...
# Preparing texts from  Football Players ...
# Preparing texts from  Reporter #4 ...
# Preparing texts from  Player #2 ...
# Preparing texts from  Linemen ...
# Preparing texts from  JODY PRICE ...
# Preparing texts from  Archie Bunker ...
# Preparing texts from  Bad Flanders ...
# Preparing texts from  Lieutenant ...
# Preparing texts from  Commander ...
# Preparing texts from  Bank Robber #1 ...
# Preparing texts from  Bank Robber #2 ...
# Preparing texts from  POLICECOP #2 ...
# Preparing texts from  POLICECOP #1 ...
# Preparing texts from  Banker ...
# Preparing texts from  DETECTIVE HOMER SIMPSON ...
# Preparing texts from  2nd Producer ...
# Preparing texts from  3rd Producer ...
# Preparing texts from  4th Producer ...
# Preparing texts from  5th Producer ...
# Preparing texts from  Saleswoman ...
# Preparing texts from  TRENT ...
# Preparing texts from  Valet ...
# Preparing texts from  Guest #1 ...
# Preparing texts from  Ed Begley, Jr. ...
# Preparing texts from  Lorne Michaels ...
# Preparing texts from  Guest #2 ...
# Preparing texts from  Bald Eagle ...
# Preparing texts from  Police Car ...
# Preparing texts from  MACAW ...
# Preparing texts from  Crewman ...
# Preparing texts from  Elton John ...
# Preparing texts from  Female S.U.V. Voice ...
# Preparing texts from  Burn Victims ...
# Preparing texts from  Sergeant Crew ...
# Preparing texts from  Astronaut In Space Suit ...
# Preparing texts from  Curtis E. Bear ...
# Preparing texts from  Lemur ...
# Preparing texts from  Australian Gamekeeper ...
# Preparing texts from  Workmen ...
# Preparing texts from  Omnitouch Rep ...
# Preparing texts from  Security Guard #2 ...
# Preparing texts from  New Age Clerk ...
# Preparing texts from  Deep Male Voice ...
# Preparing texts from  Repo Man #1 ...
# Preparing texts from  Repo Man #2 ...
# Preparing texts from  RED ...
# Preparing texts from  Cow #1 ...
# Preparing texts from  Red's Friend #1 ...
# Preparing texts from  Red's Friend #2 ...
# Preparing texts from  ABBA ...
# Preparing texts from  Missionary #1 ...
# Preparing texts from  Missionary #2 ...
# Preparing texts from  Old Lady ...
# Preparing texts from  Tourist #1 ...
# Preparing texts from  Trucker #3 ...
# Preparing texts from  Various Truckers ...
# Preparing texts from  Trucker #5 ...
# Preparing texts from  Trucker #4 ...
# Preparing texts from  Navitron Auto-drive ...
# Preparing texts from  Truckers ...
# Preparing texts from  Señor Ding-Dong ...
# Preparing texts from  Gopher ...
# Preparing texts from  Unicorn ...
# Preparing texts from  Slavedriver Willie ...
# Preparing texts from  Pharaoh Skinner ...
# Preparing texts from  BURNING BUSH ...
# Preparing texts from  Moses/milhouse ...
# Preparing texts from  LISA & MOSES/MILHOUSE ...
# Preparing texts from  Egyptians ...
# Preparing texts from  Methuselah Grampa ...
# Preparing texts from  Goliath/nelson ...
# Preparing texts from  Sheep ...
# Preparing texts from  GUARD 1 ...
# Preparing texts from  GUARD 2 ...
# Preparing texts from  Teen ...
# Preparing texts from  Tv Handyman ...
# Preparing texts from  HANDYMAN ...
# Preparing texts from  Astrid Weller ...
# Preparing texts from  Jasper Johns ...
# Preparing texts from  Human Proportions Guy ...
# Preparing texts from  Cubist Musician ...
# Preparing texts from  Andy Warhol ...
# Preparing texts from  French Representative ...
# Preparing texts from  Ioc Chairman ...
# Preparing texts from  Russian Representative ...
# Preparing texts from  Representative ...
# Preparing texts from  Latin Representative ...
# Preparing texts from  OTHER REPRESENTATIVES ...
# Preparing texts from  JAPANESE REPRESENTATIVE ...
# Preparing texts from  Olympic Representatives ...
# Preparing texts from  Swiss Representative ...
# Preparing texts from  Seniors ...
# Preparing texts from  Sweet Elderly Lady ...
# Preparing texts from  Scarlett ...
# Preparing texts from  Rhett ...
# Preparing texts from  Other Seniors ...
# Preparing texts from  Native-american Man ...
# Preparing texts from  Jack LaLanne ...
# Preparing texts from  Kevin Costner ...
# Preparing texts from  Male Host ...
# Preparing texts from  Appraiser ...
# Preparing texts from  Loch Ness Monster ...
# Preparing texts from  Everyone In Store ...
# Preparing texts from  PEOPLE ...
# Preparing texts from  Arthur Fortune ...
# Preparing texts from  Conga Line ...
# Preparing texts from  PEDESTRIANS ...
# Preparing texts from  Crickets ...
# Preparing texts from  Jerry Rude ...
# Preparing texts from  Local ...
# Preparing texts from  3rd Local ...
# Preparing texts from  Commercial Anncr ...
# Preparing texts from  Pudding Representative ...
# Preparing texts from  Horse ...
# Preparing texts from  MENSANS ...
# Preparing texts from  HAWKING ...
# Preparing texts from  Computer Voice 2 ...
# Preparing texts from  GARABEDIAN ...
# Preparing texts from  Mr. Pennybags ...
# Preparing texts from  Toilet ...
# Preparing texts from  Japanese Stewardess ...
# Preparing texts from  Jim Belushi ...
# Preparing texts from  TV CHARACTER ...
# Preparing texts from  Woody Allen ...
# Preparing texts from  Sumo ...
# Preparing texts from  Magic Fish ...
# Preparing texts from  Cartoon Squid ...
# Preparing texts from  Japanese Father ...
# Preparing texts from  Gameshow Host ...
# Preparing texts from  Canadian Man ...
# Preparing texts from  CANADIAN WOMAN ...
# Preparing texts from  Somber Announcer ...
# Preparing texts from  Salesperson ...
# Preparing texts from  Electric Car Computer ...
# Preparing texts from  WILLIAM/ROBYN ...
# Preparing texts from  Mel Gibson ...
# Preparing texts from  WILLIAM ...
# Preparing texts from  ROBYN ...
# Preparing texts from  MR.SMITH/MEL ...
# Preparing texts from  John Travolta ...
# Preparing texts from  MAN ON RIGHT ...
# Preparing texts from  MAN ON LEFT ...
# Preparing texts from  Bus Tour Guide ...
# Preparing texts from  Anne ...
# Preparing texts from  MR. SMITH/MEL ...
# Preparing texts from  Senators ...
# Preparing texts from  Senator Payne ...
# Preparing texts from  Senate Leader ...
# Preparing texts from  DISTINGUISHED-LOOKING MAN ...
# Preparing texts from  Tram Guide ...
# Preparing texts from  Irene Ryan ...
# Preparing texts from  Batman ...
# Preparing texts from  Robin ...
# Preparing texts from  EDWARD/WILLIAM/ROBYN ...
# Preparing texts from  Hosey the Bear ...
# Preparing texts from  Researcher #1 ...
# Preparing texts from  Researcher #2 ...
# Preparing texts from  Video Game ...
# Preparing texts from  Staffer ...
# Preparing texts from  Electronic Organizer ...
# Preparing texts from  Navajo Boy ...
# Preparing texts from  Dancer ...
# Preparing texts from  SOLIDIER #1 ...
# Preparing texts from  Sir Widebottom ...
# Preparing texts from  SCHOOLKIDS ...
# Preparing texts from  Satellite ...
# Preparing texts from  Mark McGwire ...
# Preparing texts from  Homer Effigy ...
# Preparing texts from  Newspaper Worker #1 ...
# Preparing texts from  Newspaper Worker #2 ...
# Preparing texts from  SHREWISH WOMAN ...
# Preparing texts from  Lifeways Editor ...
# Preparing texts from  Mimi ...
# Preparing texts from  German Man ...
# Preparing texts from  German Woman ...
# Preparing texts from  Farm Critic ...
# Preparing texts from  Tv Critic ...
# Preparing texts from  Theater Critic ...
# Preparing texts from  Herald ...
# Preparing texts from  Salvatore ...
# Preparing texts from  DINNER THEATRE OWNER ...
# Preparing texts from  Deli Owner ...
# Preparing texts from  French Chef ...
# Preparing texts from  Dinner Theater Owner ...
# Preparing texts from  RESTAURANT OWNERS ...
# Preparing texts from  CREEPY VOICE ...
# Preparing texts from  Lucy Lawless ...
# Preparing texts from  Dick Clark ...
# Preparing texts from  Band Member #1 ...
# Preparing texts from  Band Member #2 ...
# Preparing texts from  Band Member #3 ...
# Preparing texts from  Rick James ...
# Preparing texts from  WAFFLE IRON ...
# Preparing texts from  Tom Arnold ...
# Preparing texts from  Pauly Shore ...
# Preparing texts from  Rosie O'Donnell ...
# Preparing texts from  Terrible Celebrities ...
# Preparing texts from  ROSIE O'DONNEL ...
# Preparing texts from  GERMAN SOLDIER ...
# Preparing texts from  G.I. ...
# Preparing texts from  Dead German Soldier ...
# Preparing texts from  Musketeer ...
# Preparing texts from  Man In The Iron Mask ...
# Preparing texts from  Zorro ...
# Preparing texts from  Princess ...
# Preparing texts from  Scarlet Pimpernel ...
# Preparing texts from  King Arthur ...
# Preparing texts from  Rap Singer ...
# Preparing texts from  B-52'S ...
# Preparing texts from  HOMERA ...
# Preparing texts from  COLONEL'S WIFE ...
# Preparing texts from  Farmer #2 ...
# Preparing texts from  Storekeeper ...
# Preparing texts from  Elephant ...
# Preparing texts from  Sandy ...
# Preparing texts from  J.P. ...
# Preparing texts from  Laramie Employees ...
# Preparing texts from  New Yorker ...
# Preparing texts from  Burns Ball ...
# Preparing texts from  PENN ...
# Preparing texts from  Smiley the Elf ...
# Preparing texts from  Happy The Elf ...
# Preparing texts from  Giggly The Elf ...
# Preparing texts from  Pat O'Brien ...
# Preparing texts from  Nancy O'Dell ...
# Preparing texts from  Man In Line ...
# Preparing texts from  Boy In Car ...
# Preparing texts from  Girl In Car ...
# Preparing texts from  Homer Monster ...
# Preparing texts from  Allen ...
# Preparing texts from  Shelbyville Father ...
# Preparing texts from  SHELBYVILLE FATHER AND MOTHER ...
# Preparing texts from  Forklift Driver ...
# Preparing texts from  OCTUPLETS ...
# Preparing texts from  Businessman ...
# Preparing texts from  ZOO OWNER ...
# Preparing texts from  Butch Patrick ...
# Preparing texts from  Anoop ...
# Preparing texts from  Poonam ...
# Preparing texts from  Flamboyant Theater-type ...
# Preparing texts from  Uncle Sam ...
# Preparing texts from  Christopher ...
# Preparing texts from  Koala ...
# Preparing texts from  Mother Gorilla ...
# Preparing texts from  Man With No Face ...
# Preparing texts from  Fast-talking Announcer ...
# Preparing texts from  Jay North ...
# Preparing texts from  Johnny Bobby ...
# Preparing texts from  Rebel ...
# Preparing texts from  NRBQ ...
# Preparing texts from  Fretful Mother ...
# Preparing texts from  Grim Father ...
# Preparing texts from  Cop ...
# Preparing texts from  Meathook ...
# Preparing texts from  Ramrod ...
# Preparing texts from  Bikers ...
# Preparing texts from  BURLY BARTENDER ...
# Preparing texts from  NURSING STUDENTS ...
# Preparing texts from  Funzo ...
# Preparing texts from  Plaintiff ...
# Preparing texts from  Defendant ...
# Preparing texts from  Jim Hope ...
# Preparing texts from  LINDSEY ...
# Preparing texts from  Male Executive ...
# Preparing texts from  teacher ...
# Preparing texts from  Dixie Chicks ...
# Preparing texts from  Gary Coleman ...
# Preparing texts from  Goodwill Driver ...
# Preparing texts from  Chair Lift Operator ...
# Preparing texts from  Ski Instructor ...
# Preparing texts from  DEER ...
# Preparing texts from  Lodge Employee #1 ...
# Preparing texts from  Lodge Employee #2 ...
# Preparing texts from  Mr. Sakamoto ...
# Preparing texts from  Ricky ...
# Preparing texts from  Lucy ...
# Preparing texts from  Fred ...
# Preparing texts from  John Wayne ...
# Preparing texts from  RASPY VOICE ...
# Preparing texts from  Left Snake ...
# Preparing texts from  Right Snake ...
# Preparing texts from  Both Snakes ...
# Preparing texts from  Virtual Doctor ...
# Preparing texts from  Lubchenko ...
# Preparing texts from  Men's Singing Group ...
# Preparing texts from  Frat Boy #1 ...
# Preparing texts from  Frat Boy #2 ...
# Preparing texts from  Brother Faith ...
# Preparing texts from  Bart's Congregation ...
# Preparing texts from  Float Singers ...
# Preparing texts from  FAN ...
# Preparing texts from  Britney Spears ...
# Preparing texts from  SEAT FILLER ...
# Preparing texts from  Chapman ...
# Preparing texts from  Coast Guard Guy ...
# Preparing texts from  Party Guests ...
# Preparing texts from  Asian Pirate ...
# Preparing texts from  CLOSING ...
# Preparing texts from  LARGO ...
# Preparing texts from  Rat-pack Kid ...
# Preparing texts from  SALESGUY ...
# Preparing texts from  Randy Bachman ...
# Preparing texts from  Fred Turner ...
# Preparing texts from  State Comptroller Atkins ...
# Preparing texts from  COMPTROLLER ATKINS ...
# Preparing texts from  Giant Pearl ...
# Preparing texts from  Dream Homer ...
# Preparing texts from  Jockey #1 ...
# Preparing texts from  Jockey #2 ...
# Preparing texts from  Mrs. Vanderbilt ...
# Preparing texts from  Mr. Vanderbilt ...
# Preparing texts from  Jockeys ...
# Preparing texts from  Tree Jockey ...
# Preparing texts from  Toadstool Jockey ...
# Preparing texts from  Woman Jockey ...
# Preparing texts from  OTHER JOCKEYS ...
# Preparing texts from  Hank Jockey ...
# Preparing texts from  Duncan ...
# Preparing texts from  FIRST PARROT ...
# Preparing texts from  SECOND PARROT ...
# Preparing texts from  Clay Babcock ...
# Preparing texts from  Mrs. Babcock ...
# Preparing texts from  Crew Chief ...
# Preparing texts from  LINDSAY ...
# Preparing texts from  Rachel ...
# Preparing texts from  Pbs-style Announcer ...
# Preparing texts from  Teen-aged Hooligan ...
# Preparing texts from  Betty White ...
# Preparing texts from  Mr. Rogers ...
# Preparing texts from  Yo-Yo Ma ...
# Preparing texts from  Bigg Byrd ...
# Preparing texts from  Ellmeaux ...
# Preparing texts from  Craig ...
# Preparing texts from  Amy ...
# Preparing texts from  Qtoktok ...
# Preparing texts from  Ak ...
# Preparing texts from  LISA JUNIOR ...
# Preparing texts from  ISLANDERS ...
# Preparing texts from  Chipper Guide ...
# Preparing texts from  Babe Ruth ...
# Preparing texts from  Hostess ...
# Preparing texts from  Titania ...
# Preparing texts from  Phil Angelides ...
# Preparing texts from  Dr. Velimirovic ...
# Preparing texts from  Jailbird's Son ...
# Preparing texts from  Slick-looking Man #1 ...
# Preparing texts from  Slick-looking Man #2 ...
# Preparing texts from  Slick-looking Man #3 ...
# Preparing texts from  Second Nurse ...
# Preparing texts from  Other Nurses ...
# Preparing texts from  20-ISH MOE ...
# Preparing texts from  NO NONSENSE FEMALE VOICE ...
# Preparing texts from  Helen Morehouse ...
# Preparing texts from  Soap Announcer ...
# Preparing texts from  Ingenue ...
# Preparing texts from  Contessa ...
# Preparing texts from  Arthur Crandall ...
# Preparing texts from  Casino Manager ...
# Preparing texts from  Hologram Nelson ...
# Preparing texts from  Heckler ...
# Preparing texts from  Old Barney ...
# Preparing texts from  Helen Thomas ...
# Preparing texts from  Bart's Friends ...
# Preparing texts from  Advisors ...
# Preparing texts from  Security Advisor Kearney ...
# Preparing texts from  Old Krusty ...
# Preparing texts from  Billy Carter's Ghost ...
# Preparing texts from  Foreign Delegates ...
# Preparing texts from  German Delegate ...
# Preparing texts from  British Delegate ...
# Preparing texts from  French Delegate ...
# Preparing texts from  Chinese Delegate ...
# Preparing texts from  TIKI ...
# Preparing texts from  Bar Patrons ...
# Preparing texts from  Lindsay Naegle ...
# Preparing texts from  Factory Foreman ...
# Preparing texts from  Burt Reynolds ...
# Preparing texts from  Charlie Rose ...
# Preparing texts from  Robert Evans ...
# Preparing texts from  Inspector ...
# Preparing texts from  Boisterous Student ...
# Preparing texts from  Veejay ...
# Preparing texts from  Younger Veejay ...
# Preparing texts from  JOE C. ...
# Preparing texts from  Kid Rock ...
# Preparing texts from  Band ...
# Preparing texts from  Sheriff ...
# Preparing texts from  Female Student ...
# Preparing texts from  Male Student ...
# Preparing texts from  RADIO ANNCR ...
# Preparing texts from  Southern Dowager ...
# Preparing texts from  Police Captain ...
# Preparing texts from  Cyborganizer ...
# Preparing texts from  Robobaby ...
# Preparing texts from  Eduardo ...
# Preparing texts from  Dance Coach ...
# Preparing texts from  PLAIN JANE ...
# Preparing texts from  Latin Milhouse ...
# Preparing texts from  LISABELLA ...
# Preparing texts from  Little Vicki ...
# Preparing texts from  Texan Man ...
# Preparing texts from  Thought Bubble Homer ...
# Preparing texts from  ORGAN SALESMAN ...
# Preparing texts from  Mall Manager ...
# Preparing texts from  Bojangles ...
# Preparing texts from  Lion ...
# Preparing texts from  Martian Children ...
# Preparing texts from  Bret Michaels ...
# Preparing texts from  The Admiral ...
# Preparing texts from  Lead Singer ...
# Preparing texts from  Tourist ...
# Preparing texts from  Other Doctors ...
# Preparing texts from  Dr. Wilmore ...
# Preparing texts from  Waitresses ...
# Preparing texts from  Richie Rich ...
# Preparing texts from  RUPERT ...
# Preparing texts from  Crew Member ...
# Preparing texts from  Dr. Stephen Hawking ...
# Preparing texts from  Female Artist ...
# Preparing texts from  Sidekick #2 ...
# Preparing texts from  LISA'S LAWYER ...
# Preparing texts from  Willie Nelson ...
# Preparing texts from  Huckleberry Hound ...
# Preparing texts from  St. Peter ...
# Preparing texts from  Ghost Homer ...
# Preparing texts from  Snorky ...
# Preparing texts from  SCOUT ...
# Preparing texts from  SATAN ...
# Preparing texts from  Troll ...
# Preparing texts from  Goldilocks ...
# Preparing texts from  RAPUNZEL ...
# Preparing texts from  Witch ...
# Preparing texts from  Handsome Man ...
# Preparing texts from  Wild Dolphin ...
# Preparing texts from  Dumb-looking Dolphin ...
# Preparing texts from  Drive-thru Speaker ...
# Preparing texts from  THE SIMPSONS ...
# Preparing texts from  Woodpecker ...
# Preparing texts from  Phone Recording ...
# Preparing texts from  BAD AUSTIN POWERS IMPRESSION ...
# Preparing texts from  Phone Company Lady ...
# Preparing texts from  CARTOON MAN ...
# Preparing texts from  PHONEY ...
# Preparing texts from  939'ers ...
# Preparing texts from  TRANSPORTER ...
# Preparing texts from  Prospector ...
# Preparing texts from  Roger Daltrey ...
# Preparing texts from  John Entwistle ...
# Preparing texts from  Pete Townshend ...
# Preparing texts from  PETE/ROGER/JOHN ...
# Preparing texts from  Olde Springfielders ...
# Preparing texts from  Badger ...
# Preparing texts from  Sophie ...
# Preparing texts from  Stephen King ...
# Preparing texts from  "For Dummies" Author ...
# Preparing texts from  Christopher Walken ...
# Preparing texts from  Tom Clancy ...
# Preparing texts from  Maya Angelou ...
# Preparing texts from  Amy Tan ...
# Preparing texts from  AUTHOR ...
# Preparing texts from  FEMALE SOLDIER ...
# Preparing texts from  Soldiers ...
# Preparing texts from  Stereo Voice ...
# Preparing texts from  Ace of Hearts ...
# Preparing texts from  Ace of Clubs ...
# Preparing texts from  Ace of Diamonds ...
# Preparing texts from  Ace of Spades ...
# Preparing texts from  ALL FOUR ACES ...
# Preparing texts from  MAN WITH JEWELER'S LOUPE ...
# Preparing texts from  Female Teen #1 ...
# Preparing texts from  Female Teen #2 ...
# Preparing texts from  Mobsters ...
# Preparing texts from  Squealer ...
# Preparing texts from  Johnny Tightlips ...
# Preparing texts from  Old Barber ...
# Preparing texts from  Mr. Thai ...
# Preparing texts from  LEAD PROTESTER ...
# Preparing texts from  Jesse Grass ...
# Preparing texts from  Activists ...
# Preparing texts from  Caleb ...
# Preparing texts from  Wild Turkey ...
# Preparing texts from  Springfielders ...
# Preparing texts from  Male Activist ...
# Preparing texts from  Singing Waiters ...
# Preparing texts from  Scanner ...
# Preparing texts from  Financial Planner ...
# Preparing texts from  Albuquerquean Man ...
# Preparing texts from  Female Trainer ...
# Preparing texts from  Mr. Costington ...
# Preparing texts from  Leeza Gibbons ...
# Preparing texts from  CREDIT CARD SWIPER ...
# Preparing texts from  Virtual Wiggum ...
# Preparing texts from  Terrorists ...
# Preparing texts from  Head Terrorist ...
# Preparing texts from  Committee Woman ...
# Preparing texts from  Citizen #1 ...
# Preparing texts from  Citizen #2 ...
# Preparing texts from  Patrick McGoohan ...
# Preparing texts from  Blind Man ...
# Preparing texts from  Number 2 ...
# Preparing texts from  Fake Homer ...
# Preparing texts from  Questo ...
# Preparing texts from  QUESTO'S THOUGHTS ...
# Preparing texts from  Cosmonaut #1 ...
# Preparing texts from  COSMONAUT #2 ...
# Preparing texts from  PUPPETEER ...
# Preparing texts from  Silver-haired Man ...
# Preparing texts from  FBI MAN ...
# Preparing texts from  Willie's Lawyer ...
# Preparing texts from  Ex-jock #2 ...
# Preparing texts from  Ex-jock #1 ...
# Preparing texts from  EX-JOCKS ...
# Preparing texts from  Super-criminal ...
# Preparing texts from  Costume Supervisor ...
# Preparing texts from  Ex-jock #3 ...
# Preparing texts from  Disheveled Clown ...
# Preparing texts from  Ringmaster ...
# Preparing texts from  RADIO WEATHER MAN ...
# Preparing texts from  APU+ ...
# Preparing texts from  Elf #1 ...
# Preparing texts from  Hobgoblin ...
# Preparing texts from  LITTLE BO PEEP ...
# Preparing texts from  G.I. #1 ...
# Preparing texts from  Young Skinner ...
# Preparing texts from  G.I. #2 ...
# Preparing texts from  Wolf #1 ...
# Preparing texts from  Wolf #2 ...
# Preparing texts from  Company Spokesman ...
# Preparing texts from  Camel Lisa ...
# Preparing texts from  Harem Girl Bart ...
# Preparing texts from  Female Warrior ...
# Preparing texts from  A.D.R. Sessions ...
# Preparing texts from  SMOOTH ANNOUNCER ...
# Preparing texts from  Female Technician ...
# Preparing texts from  Cartoon Dog ...
# Preparing texts from  Rockettes ...
# Preparing texts from  King Kong ...
# Preparing texts from  Female Researcher ...
# Preparing texts from  Male Researcher ...
# Preparing texts from  SIX-YEAR-OLD HOMER ...
# Preparing texts from  CLASSICAL D.J. ...
# Preparing texts from  Dr. Steve ...
# Preparing texts from  Fire Inspector ...
# Preparing texts from  Groom #1 / Groom #2 ...
# Preparing texts from  Ring Bearer ...
# Preparing texts from  Movie Audience ...
# Preparing texts from  Burly Usher ...
# Preparing texts from  Octoparrot ...
# Preparing texts from  Prisoner ...
# Preparing texts from  Jack ...
# Preparing texts from  Rodeo Clown #1 ...
# Preparing texts from  Rodeo Clown #2 ...
# Preparing texts from  Sardonicus ...
# Preparing texts from  Bruce Vilanch ...
# Preparing texts from  Johnny Cochran ...
# Preparing texts from  Mrs. Prince ...
# Preparing texts from  Gallagher ...
# Preparing texts from  Tom Savini ...
# Preparing texts from  Mr. Rodgers ...
# Preparing texts from  Officer ...
# Preparing texts from  Weeping Widow ...
# Preparing texts from  Wolves ...
# Preparing texts from  Gophers ...
# Preparing texts from  Stephanie ...
# Preparing texts from  Assistant Director ...
# Preparing texts from  Black Pawn ...
# Preparing texts from  Black Rook ...
# Preparing texts from  Black King ...
# Preparing texts from  Tennis Audience ...
# Preparing texts from  Serena Williams ...
# Preparing texts from  Venus Williams ...
# Preparing texts from  SERENA ...
# Preparing texts from  Pete Sampras ...
# Preparing texts from  Andre Agassi ...
# Preparing texts from  VENUS ...
# Preparing texts from  Game Show Host ...
# Preparing texts from  GHOSTLY SIDESHOW BOB ...
# Preparing texts from  CONSERVATIVE 50'S AUDIENCE ...
# Preparing texts from  Judy Carne ...
# Preparing texts from  Frances ...
# Preparing texts from  Lighting Man ...
# Preparing texts from  SUPEREXECUTIVE ...
# Preparing texts from  Djiboutian Runner ...
# ...
# Preparing texts from  RABBI RUDENSTEIN ...
# Preparing texts from  TEENAGED KRUSTY ...
# Preparing texts from  CLIVE MERIWETHER ...
# Preparing texts from  DAVID HYDE PIERCE ...
# Preparing texts from  NEIL SIMON ...
# Preparing texts from  MIDDLE-AGED KRUSTY ...
# Preparing texts from  GERMAN HOUSEKEEPER ...
# Preparing texts from  RODNEY DANGERFIELD ...
# Preparing texts from  RESUSCI-ANNIE ...
# Preparing texts from  CAPTAIN BOWDITCH ...
# Preparing texts from  CEELO GREEN-TYPE ...
# Preparing texts from  GITMO ...
# Preparing texts from  NFL NARRATOR ...
# Preparing texts from  CAPTAIN BOWDITCH/SAILORS ...
# Preparing texts from  TRUDY ZENGLER ...
# Preparing texts from  KID DEMON ...
# Preparing texts from  BULLY DEMON ...
# Preparing texts from  SCREAMING TORSO ...
# Preparing texts from  DEMON GIRL ...
# Preparing texts from  PRINCIPAL HEAD #2 ...
# Preparing texts from  DEMON TEACHER ...
# Preparing texts from  JEFFISTOPHELES ...
# Preparing texts from  JOCK DEMON ...
# Preparing texts from  HOT STUFF ...
# Preparing texts from  PRINCIPAL HEAD #1 ...
# Preparing texts from  NOAH WEBSTER ...
# Preparing texts from  MISERABLE MAN ...
# Preparing texts from  MOOG ...
# Preparing texts from  WISEGUYS ...
# Preparing texts from  MOOG/LEONARD/CARLTON/DUM ...
# Preparing texts from  DUM ...
# Preparing texts from  LEONARD/CARLTON ...
# Preparing texts from  PARTYGOER ...
# Preparing texts from  STANLEY KUBRICK ...
# Preparing texts from  AL BUNDY ...
# Preparing texts from  PEG ALIEN ...
# Preparing texts from  ORIGINAL MARGE ...
# Preparing texts from  ORIGINAL HOMER ...
# Preparing texts from  ORIGINAL BART ...
# Preparing texts from  REGULAR GHOST MARGE ...
# Preparing texts from  REGULAR GHOST LISA ...
# Preparing texts from  REGULAR GHOST HOMER ...
# Preparing texts from  ORIGINAL GHOST MARGE ...
# Preparing texts from  REGULAR GHOST MARGE/ ORIGINAL GHOST MARGE ...
# Preparing texts from  ORIGINAL GHOST BART ...
# Preparing texts from  ORIGINAL GHOST HOMER ...
# Preparing texts from  CGI HOMER ...
# Preparing texts from  CGI DOG ...
# Preparing texts from  MINION MARGE SIMPSON ...
# Preparing texts from  MINION HOMER SIMPSON ...
# Preparing texts from  ORIGINAL GHOST LISA ...
# Preparing texts from  MAXINE LOMBARD ...
# Preparing texts from  MUTANT CHARLIE ...
# Preparing texts from  NDND ...
# Preparing texts from  MAXINE ...
# Preparing texts from  HEDONISMBOT ...
# Preparing texts from  JUKEBOX RECORD ...
# Preparing texts from  LEELA ...
# Preparing texts from  FRY ...
# Preparing texts from  PROFESSOR FARNSWORTH ...
# Preparing texts from  HERMES ...
# Preparing texts from  DR. ZOIDBERG ...
# Preparing texts from  FRY/PROFESSOR/LEELA ...
# Preparing texts from  MARGE * ...
# Preparing texts from  MORBO ...
# Preparing texts from  LINDA ...
# Preparing texts from  BART GOBLINS ...
# Preparing texts from  SCRUFFY ...
# Preparing texts from  SPOILED 2-YEAR-OLD ...
# Preparing texts from  LRRR ...
# Preparing texts from  TEACHER IN BACK ...
# Preparing texts from  MR. LASSEN ...
# Preparing texts from  DESERT HIPSTER ...
# Preparing texts from  CUPCAKE MAN ...
# Preparing texts from  BLAZING GUY VETERAN ...
# Preparing texts from  HIPSTER WOMAN ...
# Preparing texts from  TUBA PLAYER ...
# Preparing texts from  BLAZING GUY HIPSTER ...
# Preparing texts from  FIRE PRIESTESS ...
# Preparing texts from  2ND REVELER ...
# Preparing texts from  MAN IN CENTER OF PRISON ...
# Preparing texts from  NELSON COMET ...
# Preparing texts from  KING TOOT ...
# Preparing texts from  GUITAR CENTRAL EMPLOYEE #1 ...
# Preparing texts from  STIG ...
# Preparing texts from  SUNGAZER SINGER ...
# Preparing texts from  NICK DELACOURT ...
# Preparing texts from  PETER D'ABBRUZIO ...
# Preparing texts from  SHREDDER STEVENS ...
# Preparing texts from  LORDS OF ROCK ...
# Preparing texts from  SAMMY HAGAR ...
# Preparing texts from  COVERCRAFT ...
# Preparing texts from  FREDDY FREEMAN ...
# Preparing texts from  FORUM ANNOUNCER ...
# Preparing texts from  R3 ...
# Preparing texts from  GOLDEN ROBOT ...
# Preparing texts from  KARAOKE MACHINE ...
# Preparing texts from  WISEGUY VENDOR ...
# Preparing texts from  BLUE ...
# Preparing texts from  NUTCRACKER ...
# Preparing texts from  SCARECROW ...
# Preparing texts from  ITALIAN FATHER ...
# Preparing texts from  WISE ELDERLY ALIEN ...
# Preparing texts from  PIRATES ...
# Preparing texts from  MANIC MOUSE ...
# Preparing texts from  COOL ZONE RECORDING ...
# Preparing texts from  PARKGOERS ...
# Preparing texts from  ALIEN PORN STAR/FEMALE ALIEN PORN STAR ...
# Preparing texts from  FLYING SQUIRREL ...
# Preparing texts from  ALIEN ATTORNEY ...
# Preparing texts from  BAGPIPER ...
# Preparing texts from  ALIEN MOM ...
# Preparing texts from  ALIEN MOM/ALIEN KIDS ...
# Preparing texts from  YOUNG FEMALE CREATURE ...
# Preparing texts from  INTELLECTUAL ALIEN ...
# Preparing texts from  ALIEN ANNOUNCER #1 ...
# Preparing texts from  KLAUNAX ...
# Preparing texts from  SWEET MALE VOICES ...
# Preparing texts from  GENTLE VOICE ...
# Preparing texts from  ALIEN MAN ...
# Preparing texts from  SPACE BROCCOLI ...
# Preparing texts from  HOMER) ...
# Preparing texts from  DON BOOKNER ...
# Preparing texts from  CIRCUS AUDIENCE ...
# Preparing texts from  FINGERNAIL MAN ...
# Preparing texts from  SVEN-GOLLY ...
# Preparing texts from  ELON MUSK ...
# Preparing texts from  ELON ...
# Preparing texts from  IMAGINER ...
# Preparing texts from  YOUNG JEWISH MAN ...
# Preparing texts from  YOUNG MOLEMAN ...
# Preparing texts from  TUSCALOOSA PEOPLE ...
# Preparing texts from  PHARRELL WILLIAMS ...
# Preparing texts from  PRIDESTERS ...
# Preparing texts from  ALBERT ...
# Preparing texts from  LANEY FONTAINE ...
# Preparing texts from  LADY DUFF ...
# Preparing texts from  BOOK CLUB MEMBER ...
# Preparing texts from  OTHER BOOK CLUB MEMBER ...
# Preparing texts from  HEAD INSPECTOR ...
# Preparing texts from  SIKH CAB DRIVER ...
# Preparing texts from  JIM IGNATOWSKI ...
# Preparing texts from  CHAPIN-LIKE SINGER ...
# Preparing texts from  HARRY CHAPIN-TYPE SINGER ...
# Preparing texts from  CABBIES ...
# Preparing texts from  SMILE ...
# Preparing texts from  KEMI ...
# Preparing texts from  PEDICAB DRIVER ...
# Preparing texts from  SMITHERS' THOUGHTS ...
# Preparing texts from  AGED MOE ...
# Preparing texts from  RICHARD BRANSON ...
# Preparing texts from  CHURCH GROUP ...
# Preparing texts from  COCKTAIL WAITRESSES ...
# Preparing texts from  SECURITY THUG #1 ...
# Preparing texts from  SECURITY THUG #2 ...
# Preparing texts from  LATINO WORKERS ...
# Preparing texts from  KRABAPPEL ...
# Preparing texts from  BLEEDING GUMS ...
# Preparing texts from  BROCKMAN ...
# Preparing texts from  ROGER MYERS, JR. ...
# Preparing texts from  MEYERS ...
# Preparing texts from  McBain ...
# Preparing texts from  WOLFCASTLE ...
# Preparing texts from  G. K. Willington ...
# Preparing texts from  Teenage Homer ...
# Preparing texts from  Young Krusty ...
# Preparing texts from  Teenage Bart ...
# Preparing texts from  Adult "Bart" ...
# Preparing texts from  Kirk Voice Milhouse ...
# Preparing texts from  Tattoo Man ...
# Preparing texts from  DOCTOR ZITSOFSKY ...
# Preparing texts from  Bubbles ...
# Preparing texts from  Moldy ...
# Preparing texts from  Dog's Owner ...
# Preparing texts from  Rod #2 ...
# Preparing texts from  Ms. Melon ...
# Preparing texts from  Sydney ...
# Preparing texts from  Cecile Shapiro ...
# Preparing texts from  Ian ...
# Preparing texts from  Calvin ...
# Preparing texts from  Rod #1 ...
# Preparing texts from  Smilin' Joe Fission ...
# Preparing texts from  RODS ...
# Preparing texts from  Workman #1 ...
# Preparing texts from  TERRI & SHERRI ...
# Preparing texts from  PUNK TEENAGER ...
# Preparing texts from  Jingle Chorus ...
# Preparing texts from  Old Man Winfield ...
# Preparing texts from  Councilman #1 ...
# Preparing texts from  Councilman #2 ...
# Preparing texts from  COUNCILMEN #1/#2 ...
# Preparing texts from  Demonstrator #1 ...
# Preparing texts from  MR. GAMMILL ...
# Preparing texts from  Mrs. Long ...
# Preparing texts from  Wife #1 ...
# Preparing texts from  Wife #2 ...
# Preparing texts from  Nice Father ...
# Preparing texts from  Nice Boy ...
# Preparing texts from  NICE GIRL ...
# Preparing texts from  Nice Mother ...
# Preparing texts from  NICE FAMILY ...
# Preparing texts from  Williams Boy ...
# Preparing texts from  Mr. Williams ...
# Preparing texts from  BOXING ANNOUNCER ...
# Preparing texts from  TV-STATION ANNOUNCER ...
# Preparing texts from  Tv Wife ...
# Preparing texts from  Tv Husband ...
# Preparing texts from  Pawn Broker ...
# Preparing texts from  Homer-ish Husband ...
# Preparing texts from  ALL AT THE TABLE ...
# Preparing texts from  Homer's Image ...
# Preparing texts from  Ms. Barr ...
# Preparing texts from  Boy Onlooker ...
# Preparing texts from  Champ ...
# Preparing texts from  NED ...
# Preparing texts from  Homer's Canyon Echo ...
# Preparing texts from  Camper Father ...
# Preparing texts from  Camper Mother ...
# Preparing texts from  Game Warden ...
# Preparing texts from  Flunky ...
# Preparing texts from  Map Boy ...
# Preparing texts from  German Scientist ...
# Preparing texts from  Beautiful French Scientist ...
# Preparing texts from  English Scientist ...
# Preparing texts from  Radio Announcer #1 ...
# Preparing texts from  Churchgoing Woman ...
# Preparing texts from  Girl On Screen ...
# Preparing texts from  Boy On Screen ...
# Preparing texts from  Mr. Dandy ...
# Preparing texts from  Radio Announcer #3 ...
# Preparing texts from  TV ANNOUNCER #3 CONT'D ...
# Preparing texts from  Waiters ...
# Preparing texts from  1st Waiter Quartet ...
# Preparing texts from  2nd Waiter Quartet ...
# Preparing texts from  3rd Waiter Quartet ...
# Preparing texts from  4TH QUARTET OF WAITERS ...
# Preparing texts from  Counter Guy ...
# Preparing texts from  Eugene Fisk ...
# Preparing texts from  Mr. Fisk ...
# Preparing texts from  Female Mail Carrier ...
# Preparing texts from  Hoyt ...
# Preparing texts from  Freddie ...
# Preparing texts from  Lewis's Dad ...
# Preparing texts from  Funky Guy ...
# Preparing texts from  Man At Door ...
# Preparing texts from  Ticket-seller ...
# Preparing texts from  Theatre-goer #1 ...
# Preparing texts from  Theatre-goer #2 ...
# Preparing texts from  Theatre-goer #3 ...
# Preparing texts from  Adil Hoxha ...
# Preparing texts from  Military Man ...
# Preparing texts from  MARGE & BART ...
# Preparing texts from  Cia Agent #1 ...
# Preparing texts from  Cia Agent #2 ...
# Preparing texts from  ITCHY & SCRATCHY CHORUS ...
# Preparing texts from  Police Artist ...
# Preparing texts from  Foreperson ...
# Preparing texts from  Merchandiser #1 ...
# Preparing texts from  Merchandiser #3 ...
# Preparing texts from  Kbbl Weatherman ...
# Preparing texts from  Screener ...
# Preparing texts from  Worker One ...
# Preparing texts from  Lucille Botzcowski ...
# Preparing texts from  Doofy ...
# Preparing texts from  U-Squeal Operator ...
# Preparing texts from  Tv Reporter ...
# Preparing texts from  Krabappel's Mouth ...
# Preparing texts from  Nurse Farrell ...
# Preparing texts from  Dr. H. Boyle ...
# Preparing texts from  Entire Town ...
# Preparing texts from  John Adams ...
# Preparing texts from  Samuel Chase ...
# Preparing texts from  Roger Sherman ...
# Preparing texts from  Tv Contestant ...
# Preparing texts from  Good-looking Man ...
# Preparing texts from  Mr. Winfield ...
# Preparing texts from  Mourners ...
# Preparing texts from  Other Runner ...
# Preparing texts from  Jake ...
# Preparing texts from  Karl ...
# Preparing texts from  Woman Applicant ...
# Preparing texts from  Man In Tuxedo ...
# Preparing texts from  Moving Man ...
# Preparing texts from  House ...
# Preparing texts from  Serak The Preparer ...
# Preparing texts from  V.O. ...
# Preparing texts from  Chief Inspector ...
# Preparing texts from  Raven ...
# Preparing texts from  Dean Danielson ...
# Preparing texts from  DANIELSON ...
# Preparing texts from  DANEILSON ...
# Preparing texts from  OLD BEARDED GUY ...
# Preparing texts from  Charles Darwin ...
# Preparing texts from  MARY BAILEY ...
# Preparing texts from  Investigator #1 ...
# Preparing texts from  Investigator #2 ...
# Preparing texts from  Investigator #3 ...
# Preparing texts from  Make-up Man ...
# Preparing texts from  Gregor ...
# Preparing texts from  Man On Bus ...
# Preparing texts from  GAMMILL ...
# Preparing texts from  FLASH ...
# Preparing texts from  Dan Hoard ...
# Preparing texts from  VENDER ...
# Preparing texts from  MR. O'HARA ...
# Preparing texts from  Rasta #1 ...
# Preparing texts from  Rasta #2 ...
# Preparing texts from  Tony Bennett ...
# Preparing texts from  Dave Glass ...
# Preparing texts from  First Wife #3 ...
# Preparing texts from  First Wife #1 ...
# Preparing texts from  Hot Dog Man ...
# Preparing texts from  Spectator #1 ...
# Preparing texts from  Spectator #2 ...
# Preparing texts from  Spectator #3 ...
# Preparing texts from  Clubhouse Attendant ...
# Preparing texts from  Dave Rosenfield ...
# Preparing texts from  BURNS LAWYER ...
# Preparing texts from  SENIOR CITIZENS ...
# Preparing texts from  ANNOUNCER # ...
# Preparing texts from  Mrs. Spencer ...
# Preparing texts from  Casey ...
# Preparing texts from  Platoon ...
# Preparing texts from  Transient ...
# Preparing texts from  Tv Voice #1 ...
# Preparing texts from  Tv Voice #2 ...
# Preparing texts from  Tv Voice #3 ...
# Preparing texts from  ALL THREE TV VOICES ...
# Preparing texts from  ALL 3 ANNOUNCERS ...
# Preparing texts from  SCRAPER ...
# Preparing texts from  CLARK ...
# Preparing texts from  MURDOCK ...
# Preparing texts from  SMYTHE ...
# Preparing texts from  Itchy & Scratchy Singers ...
# Preparing texts from  Her Group ...
# Preparing texts from  Animator ...
# Preparing texts from  1ST BOARD MEMBER ...
# Preparing texts from  2nd Board Member ...
# Preparing texts from  Della ...
# Preparing texts from  Sushi Bar Chefs ...
# Preparing texts from  Toshiro ...
# Preparing texts from  Master ...
# Preparing texts from  Richie Sakai ...
# Preparing texts from  Cellmate ...
# Preparing texts from  Crazy Calls ...
# Preparing texts from  LARRY KING V.O. ...
# Preparing texts from  Bald One ...
# Preparing texts from  Fat One ...
# Preparing texts from  Kim ...
# Preparing texts from  Estelle ...
# Preparing texts from  MCINTYRE ...
# Preparing texts from  Mrs. Bloominstein ...
# Preparing texts from  Coach Flanagan ...
# Preparing texts from  Mr. Seckofsky ...
# Preparing texts from  PRINCIPAL ...
# Preparing texts from  Homer The Thief ...
# Preparing texts from  Hezron ...
# Preparing texts from  Zohar ...
# Preparing texts from  Moses ...
# Preparing texts from  Cable Guy ...
# Preparing texts from  Comic ...
# Preparing texts from  Mexican Announcer ...
# Preparing texts from  Cockfight Announcer ...
# Preparing texts from  Davey ...
# Preparing texts from  Goliath ...
# Preparing texts from  Panelist #1 ...
# Preparing texts from  Blockbuster Announcer ...
# Preparing texts from  Top Hat Announcer ...
# Preparing texts from  Stock Reporter ...
# Preparing texts from  Boxing Announcer #1 ...
# Preparing texts from  Boxing Announcer #2 ...
# Preparing texts from  Challenger ...
# Preparing texts from  Busboy ...
# Preparing texts from  Australian Boy ...
# Preparing texts from  Australian Girl ...
# Preparing texts from  Jeweler ...
# Preparing texts from  Board Member ...
# Preparing texts from  Female Commando ...
# Preparing texts from  Theatre Manager ...
# Preparing texts from  Floozy ...
# Preparing texts from  Head Engineer ...
# Preparing texts from  Engineer #3 ...
# Preparing texts from  Counter Man ...
# Preparing texts from  Father McGrath ...
# Preparing texts from  Salesboy ...
# Preparing texts from  Hula Woman ...
# Preparing texts from  BEA ...
# Preparing texts from  Checker ...
# Preparing texts from  Tracker ...
# Preparing texts from  Mr. Hazelwood ...
# Preparing texts from  KENT ...
# Preparing texts from  MONROE ...
# Preparing texts from  Old Man Daly ...
# Preparing texts from  Old Man McGrath ...
# Preparing texts from  Plato ...
# Preparing texts from  Old Woman In Line ...
# Preparing texts from  Monitor #1 ...
# Preparing texts from  Monitor #2 ...
# Preparing texts from  Female Newscaster ...
# Preparing texts from  Mr. Schindler ...
# Preparing texts from  Registrar ...
# Preparing texts from  Professor Lombardo ...
# Preparing texts from  MR. BURNS' GEOMETRIC SHAPES ...
# Preparing texts from  RINGO ...
# Preparing texts from  WETHERBY ...
# Preparing texts from  MRS. HOOVER ...
# Preparing texts from  Classmate ...
# Preparing texts from  Woman In Booth ...

# %%
character_texts[0]
# Out:
# TaggedDocument(words=['no', 'actually', 'it', 'was', 'a', 'little', 'of', 'both', 'sometimes', 'when', 'a', 'disease', 'is', 'in', 'all', 'the', 'magazines', 'and', 'all', 'the', 'news', 'shows', 'its', 'only', 'natural', 'that', 'you', 'think', 'you', 'have', 'it', 'i', 'dont', 'know', 'although', 'id', 'sure', 'like', 'to', 'talk', 'to', 'him', 'he', 'didnt', 'touch', 'my', 'lesson', 'plan', 'what', 'did', 'he', 'teach', 'you', 'thank', 'you', 'ralph', 'very', 'graphic', 'lisa', 'simpson', 'would', 'you', 'like', 'to', 'read', 'your', 'essay', 'dear', 'god', 'i', 'question', 'the', 'educational', 'value', 'of', 'this', 'assembly', 'edna', 'happy', 'hour', 'in', 'the', 'teachers', 'lounge', 'wow', 'a', 'million', 'poets', 'working', 'for', 'a', 'million', 'years', 'youre', 'so', 'lucky', 'when', 'are', 'you', 'gonna', 'meet', 'him', 'uh', 'huh', 'were', 'going', 'to', 'take', 'a', 'test', 'its', 'called', 'the', 'career', 'aptitude', 'normalizing', 'test', 'or', 'cant', 'question', 'sixty', 'i', 'prefer', 'the', 'smell', 'of', 'a', 'gasoline', 'b', 'french', 'fries', 'or', 'c', 'bank', 'customers', 'since', 'we', 'have', 'fifteen', 'minutes', 'until', 'recess', 'please', 'put', 'down', 'your', 'pencils', 'and', 'stare', 'at', 'the', 'front', 'of', 'the', 'room', 'now', 'take', 'some', 'paste', 'and', 'spread', 'it', 'on', 'the', 'construction', 'paper', 'ralph', 'are', 'you', 'eating', 'your', 'paste', 'good', 'now', 'sprinkle', 'your', 'sparkles', 'on', 'your', 'paste', 'lisa', 'youre', 'not', 'sprinkling', 'your', 'sparkles', 'nan', 'now', 'lets', 'correct', 'our', 'homework', 'exercises', 'lisa', 'what', 'nineteenth', 'century', 'figure', 'was', 'nicknamed', 'old', 'hickory', 'lisa', 'if', 'youd', 'bothered', 'to', 'do', 'the', 'assignment', 'youd', 'know', 'the', 'answer', 'is', 'the', 'battle', 'of', 'new', 'orleans', 'i', 'mean', 'andrew', 'jackson', 'ive', 'got', 'to', 'get', 'out', 'of', 'here', 'calm', 'blue', 'ocean', 'calm', 'blue', 'ocean', 'calm', 'blue', 'ocean', 'calm', 'blue', 'ocean', 'class', 'for', 'tomorrow', 'i', 'want', 'you', 'to', 'write', 'a', 'report', 'on', 'copernicus', 'here', 'are', 'your', 'final', 'report', 'cards', 'i', 'have', 'nothing', 'left', 'to', 'say', 'to', 'any', 'of', 'you', 'so', 'if', 'nobody', 'minds', 'lets', 'just', 'quietly', 'run', 'out', 'the', 'clock', 'arithmetic', 'a', 'social', 'studies', 'a', 'conduct', 'b', 'english', 'a', 'art', 'a', 'pe', 'a', 'now', 'lisa', 'everyone', 'needs', 'a', 'blotch', 'on', 'their', 'permanent', 'record', 'lisa', 'youre', 'hurting', 'me', 'mr', 'simpson', 'i', 'just', 'wanted', 'to', 'tell', 'you', 'that', 'youve', 'done', 'a', 'wonderful', 'job', 'with', 'lisa', 'you', 'must', 'have', 'read', 'to', 'her', 'at', 'a', 'young', 'age', 'uh', 'wed', 'like', 'the', 'desk', 'back', 'mr', 'simpson', 'children', 'its', 'time', 'for', 'your', 'history', 'lesson', 'put', 'on', 'your', 'virtual', 'reality', 'helmets', 'i', 'hear', 'those', 'things', 'are', 'awfully', 'loud', 'thank', 'you', 'for', 'coming', 'mr', 'lanley', 'im', 'miss', 'hoover', 'oh', 'you', 'not', 'just', 'yet', 'janey', 'first', 'were', 'going', 'to', 'construct', 'paper', 'mailboxes', 'to', 'store', 'the', 'valentines', 'bullseye', 'get', 'cracking', 'yes', 'ralph', 'the', 'children', 'are', 'right', 'to', 'laugh', 'at', 'you', 'ralph', 'these', 'things', 'couldnt', 'cut', 'butter', 'now', 'take', 'out', 'your', 'red', 'crayons', 'yes', 'ralph', 'why', 'not', 'all', 'right', 'children', 'you', 'may', 'now', 'exchange', 'valentines', 'thank', 'you', 'rex', 'ive', 'selected', 'the', 'cast', 'for', 'our', 'presidents', 'day', 'pageant', 'martha', 'washington', 'will', 'be', 'played', 'by', 'lisa', 'simpson', 'george', 'washington', 'will', 'be', 'played', 'by', 'ralph', 'wiggum', 'sit', 'down', 'rex', 'thats', 'absurd', 'rex', 'ralph', 'won', 'the', 'part', 'fair', 'and', 'square', 'bart', 'do', 'you', 'want', 'to', 'play', 'john', 'wilkes', 'booth', 'or', 'do', 'you', 'want', 'to', 'a ...

# %%
model = Doc2Vec(vector_size=50, min_count=2, epochs=40)

# %%
## estimate doc2vec model (this takes some patience as well)
model.build_vocab(character_texts)
model.train(character_texts, total_examples=model.corpus_count, epochs=model.epochs)

# %%
## now you can obtain the character embeddings...
model.dv['Homer Simpson']
# Out:
# array([ 2.3614736 ,  0.99737173, -3.9138482 ,  4.839447  ,  2.20663   ,
#         0.33646578,  6.6212215 ,  4.736256  ,  0.13752466,  2.6009717 ,
#        -4.063797  , -0.37151784, -2.155413  ,  1.1797917 , -0.5515328 ,
#         0.37091807, -5.843089  ,  3.039292  , -2.2861476 ,  1.090904  ,
#        -3.4881413 , -3.9771202 , -2.4565377 ,  2.4754605 , -2.0532982 ,
#         2.242744  , -0.3775985 ,  5.5500937 ,  1.802473  ,  1.7271515 ,
#         2.7093966 ,  3.3931673 , -3.4395266 ,  0.14850111,  3.5473256 ,
#         4.998509  ,  1.770986  , -1.287491  , -0.3807531 ,  2.3244464 ,
#         3.8806071 ,  3.3065553 , -1.3011662 , -2.7539718 , -0.62877804,
#         0.4543488 ,  2.9181368 , -2.185379  ,  2.9197237 ,  0.05911633],
#       dtype=float32)

# %%
## ...run a dimensionality reduction...
pca = PCA(n_components=2)
pca.fit(model.dv[model.dv.index_to_key])
dv_2d = pca.transform(model.dv[model.dv.index_to_key])
dv_2d = pd.DataFrame(dv_2d, index = model.dv.index_to_key)

# %%
import matplotlib.pyplot as plt
import random
random.seed(0)

plt.scatter(dv_2d[0], dv_2d[1])
plt.show()

# %%
## ...scale them using word vectors...
cool_boring_scale = model.wv['cool'] - model.wv['boring']
print("Coolness of Homer: ", cos_sim(model.dv['Homer Simpson'], cool_boring_scale))
print("Coolness of Bart: ", cos_sim(model.dv['Bart Simpson'], cool_boring_scale))
# Out:
# Coolness of Homer:  0.048026223
# Coolness of Bart:  0.36392462

# %%
## ...or predict vectors for new documents...
new_document = [
    "it", "wont", "last", "brothers", "and", "sisters", "are", "natural",
    "enemies", "like", "englishmen", "and", "scots", "or", "welshmen", "and",
    "scots", "or", "japanese", "and", "scots", "or", "scots", "and", "other",
    "scots", "damn", "scots", "they", "ruined", "scotland"
]
vector= model.infer_vector(new_document)

# %%
## ...and compare them
model.dv.most_similar([vector], topn=5)
# Out:
# [('Crypt Keeper Willie', 0.7176146507263184),
#  ('Milton Burkhart', 0.7068861126899719),
#  ('1st Class Stewardess', 0.7046352028846741),
#  ('Madonna', 0.7042320966720581),
#  ('Woman In Crowd', 0.6882516145706177)]
